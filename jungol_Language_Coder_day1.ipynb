# %% [markdown]
# # 501 : 출력 - 자가진단1
#
# ![스크린샷 2022-06-04 오후 3.00.45.png](data:image/png;base64,...)
#
# 출처 : 자기주도C언어프로그래밍

# %%
print("Fun Programming!")
# Out:
# Fun Programming!

# %% [markdown]
# # 502 : 출력 - 자가진단2
# ![스크린샷 2022-06-04 오후 3.02.26.png](data:image/png;base64,...)
#
# 출처 : 자기주도C언어프로그래밍

# %%
print("Programming! It's fun.")
# Out:
# Programming! It's fun.

# %% [markdown]
# # 503 : 출력 - 자가진단3
#
# ![스크린샷 2022-06-04 오후 3.03.35.png](data:image/png;base64,...)
#
# 출처 : 자기주도C언어프로그래밍

# %%
print("My name is Hong Gil Dong. \nI am 13 years old.")
# Out:
# My name is Hong Gil Dong.
# I am 13 years old.

# %% [markdown]
# #  504 : 출력 - 자가진단4
#
# ![스크린샷 2022-06-04 오후 3.04.18.png](data:image/png;base64,...)
#
# 출처 : 자기주도C언어프로그래밍

# %%
print("(@) (@) \n(=^.^=)\n(-m-m-)")
# Out:
# (@) (@)
# (=^.^=)
# (-m-m-)

# %% [markdown]
# # 505 : 출력 - 자가진단5
#
# ![스크린샷 2022-06-04 오후 3.05.11.png](data:image/png;base64,...)
#
# 출처 : 자기주도C언어프로그래밍

# %%
print("I can program well. \nDreams come true.")
# Out:
# I can program well.
# Dreams come true.

# %% [markdown]
# # 506 : 출력 - 자가진단6
# ![스크린샷 2022-06-04 오후 3.06.14.png](data:image/png;base64,...)
#
# 출처 : 자기주도C언어프로그래밍

# %%
print("My height\n170\nMy weight\n68.600000")
# Out:
# My height
# 170
# My weight
# 68.600000

# %%
# or
height = 170
weight = 68.600000

print('My height')
print(height)
print('My weight')
print(format(weight, ".6f"))
# Out:
# My height
# 170
# My weight
# 68.600000

# %% [markdown]
# # 507 : 출력 - 자가진단7
# ![스크린샷 2022-06-04 오후 3.07.18.png](data:image/png;base64,...)
#
#
# 출처 : 자기주도C언어프로그래밍

# %%
print("5 Dan \n5 * 2 = 10")
# Out:
# 5 Dan
# 5 * 2 = 10

# %%
# or

a = 5
b = 2
print('{} Dan'.format(a))
print('{} * {} = {}'.format(a,b,a*b))
# Out:
# 5 Dan
# 5 * 2 = 10

# %% [markdown]
# # 508 : 출력 - 자가진단8
# ![스크린샷 2022-06-04 오후 3.07.52.png](data:image/png;base64,...)
#
# 출처 : 자기주도C언어프로그래밍

# %%
# 가운데, 오른쪽, 왼쪽 정렬
# example
print('aaa'.center(10))
print('aaa'.rjust(10))
print('aaa'.ljust(10))
# Out:
#    aaa
#        aaa
# aaa

# %%
print("item".rjust(10),end='')
print("count".rjust(10),end='')
print("price".rjust(10))

print("pen".rjust(10),end='')
print("20".rjust(10),end='')
print("100".rjust(10))

print("note".rjust(10),end='')
print("5".rjust(10),end='')
print("95".rjust(10))

print("eraser".rjust(10),end='')
print("110".rjust(10),end='')
print("97".rjust(10))
# Out:
#       item     count     price
#        pen        20       100
#       note         5        95
#     eraser       110        97

# %% [markdown]
# # 101 : 출력 - 형성평가1
# ![스크린샷 2022-06-04 오후 3.13.25.png](data:image/png;base64,...)
#
# 출처 : 자기주도C언어프로그래밍

# %%
print("My name is Hong")
# Out:
# My name is Hong

# %% [markdown]
# #  102 : 출력 - 형성평가2
# ![스크린샷 2022-06-04 오후 3.14.18.png](data:image/png;base64,...)
#
# 출처 : 자기주도C언어프로그래밍

# %%
print("My hometown\nFlowering mountain")
# Out:
# My hometown
# Flowering mountain

# %% [markdown]
# # 103 : 출력 - 형성평가3
# ![스크린샷 2022-06-04 오후 3.15.33.png](data:image/png;base64,...)
#
# 출처 : 자기주도C언어프로그래밍

# %%
print("T"*10)
print("T"*10)
print("TT".center(10))
print("TT".center(10))
print("TT".center(10))
# Out:
# TTTTTTTTTT
# TTTTTTTTTT
#     TT
#     TT
#     TT

# %% [markdown]
# # 104 : 출력 - 형성평가4
# ![스크린샷 2022-06-04 오후 3.18.13.png](data:image/png;base64,...)
#
# 출처 : 자기주도C언어프로그래밍

# %%
kor = 90
mat = 80
eng = 100
sum = kor + mat + eng
print(f"kor {kor}")
print(f"mat {mat}")
print(f"eng {eng}")
print(f"sum {sum}")
# Out:
# kor 90
# mat 80
# eng 100
# sum 270

# %% [markdown]
# # 105 : 출력 - 형성평가5
# ![스크린샷 2022-06-04 오후 3.21.18.png](data:image/png;base64,...)
#
# 출처 : 자기주도C언어프로그래밍

# %%
print("Seoul".rjust(15),end='')
print("10,312,545".rjust(15),end='')
print("+91,375".rjust(15))

print("Pusan".rjust(15),end='')
print("3,567,910".rjust(15),end='')
print("+5,868".rjust(15))

print("Incheon".rjust(15),end='')
print("2,758,296".rjust(15),end='')
print("+64,888".rjust(15))

print("Daegu".rjust(15),end='')
print("2,511,676".rjust(15),end='')
print("+17,230".rjust(15))

print("Gwangju".rjust(15),end='')
print("1,454,636".rjust(15),end='')
print("+29,774".rjust(15))
# Out:
#           Seoul     10,312,545        +91,375
#           Pusan      3,567,910         +5,868
#         Incheon      2,758,296        +64,888
#           Daegu      2,511,676        +17,230
#         Gwangju      1,454,636        +29,774
